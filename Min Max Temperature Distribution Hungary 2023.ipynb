# %%
autosave 0
# Out:
# Autosave disabled

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from joypy import joyplot
from pandas.api.types import CategoricalDtype

warnings.filterwarnings("ignore")

# %%
df = pd.read_excel("temperatures Hungary 2023.xlsx")

df['Month'] = df['Month'].astype(CategoricalDtype(df['Month'].unique()))

# %%
df
# Out:
#      Day     Month  min_temp  max_temp
# 0      1   January         2        10
# 1      2   January         5        12
# 2      3   January         5        11
# 3      4   January         1        10
# 4      5   January         3        10
# ..   ...       ...       ...       ...
# 360   27  December         4        11
# 361   28  December         0         9
# 362   29  December         0         9
# 363   30  December         0        10
# 364   31  December         5         9
#
# [365 rows x 4 columns]

# %%
plt.figure()

ax, fig = joyplot(
    data=df[['min_temp', 'max_temp', 'Month']], 
    by='Month',
    column=['min_temp', 'max_temp'],
    color=['#2471A3', '#fe7c73'],
    alpha=0.75,
    figsize=(12, 12),
)
ax.suptitle('Min Max Temperature Distribution Hungary 2023', fontsize=20)

plt.show()

# %%
ax.savefig('Min Max Temperature Distribution Hungary 2023.pdf', format='pdf', dpi=300)
